# %% [markdown]
# ## Panda Series

# %% [markdown]
# ## A series is a one dimensional labels array capable of holding any datatype.The axis labeled are collectively called index

# %% [markdown]
# ## creating series

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([1,2,3])
dict = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
