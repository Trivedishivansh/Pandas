# %% [markdown]
# ## Data Frames

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df1 = pd.DataFrame(data_list)
columns = ["Name","Age","City","salary"]
df1 = pd.DataFrame(data_list,columns = columns)
df1
# Out:
#     Name  Age      City  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Selction and indexing of column

# %%
df1
# Out:
#     Name  Age      City  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df1["City"]
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df1[["Name","City"]] #For targeting two colums list ni andar list
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df1["Designation"] = ["Doctor","Engineer","Teacher","Lawyar"]

# %%
df1
# Out:
#     Name  Age      City  salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000     Teacher
# 3  Linda   42    London   85000      Lawyar

# %% [markdown]
# # remove cloumns

# %%
df1
# Out:
#     Name  Age      City  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# # selecting row

# %%
df1.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# salary       65000
# Name: 0, dtype: object

# %%
df1.loc[[0,1]]
# Out:
#    Name  Age      City  salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# # selecting subsets and row of colums

# %%
df1.loc[[0,1]][["City","salary"]]
# Out:
#        City  salary
# 0  New York   65000
# 1     Paris   70000

# %%
df1.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# # conditional selection

# %%
df1
# Out:
#     Name  Age      City  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df1[df1['Age'] > 30]
# Out:
#     Name  Age    City  salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df1[(df1['Age'] > 30) & (df1['City'] == 'Paris')]
# Out:
#    Name  Age   City  salary
# 1  Anna   34  Paris   70000
